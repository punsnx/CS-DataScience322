# %% [markdown]
# # Introduction to pandas

# %%
import pandas as pd
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
player_df= pd.read_csv("players.csv") # read the csv file

# %%
player_df.head() # show the first 5 rows
# Out:
#      surname     team    position  minutes  shots  passes  tackles  saves  \
# 0     Abdoun  Algeria  midfielder       16      0       6        0      0
# 1    Belhadj  Algeria    defender      270      1     146        8      0
# 2  Boudebouz  Algeria  midfielder       74      3      28        1      0
# 3  Bougherra  Algeria    defender      270      1      89       11      0
# 4   Chaouchi  Algeria  goalkeeper       90      0      17        0      2
#
#    Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0         NaN         NaN  ...          NaN          NaN          NaN
# 1         NaN         NaN  ...          NaN          NaN          NaN
# 2         NaN         NaN  ...          NaN          NaN          NaN
# 3         NaN         NaN  ...          NaN          NaN          NaN
# 4         NaN         NaN  ...          NaN          NaN          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# ...

# %%
type(player_df)
# Out:
# pandas.core.frame.DataFrame

# %%
player_df.shape
# Out:
# (595, 26)

# %%
player_df.shape[0]
# Out:
# 595

# %%
player_df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
# ...

# %%
player_df.index
# Out:
# RangeIndex(start=0, stop=595, step=1)

# %% [markdown]
# # SELECTION

# %%
player_df.iloc[ 2, 3 ]
# Out:
# 74

# %%
player_df.head(10)
# Out:
#      surname     team    position  minutes  shots  passes  tackles  saves  \
# 0     Abdoun  Algeria  midfielder       16      0       6        0      0
# 1    Belhadj  Algeria    defender      270      1     146        8      0
# 2  Boudebouz  Algeria  midfielder       74      3      28        1      0
# 3  Bougherra  Algeria    defender      270      1      89       11      0
# 4   Chaouchi  Algeria  goalkeeper       90      0      17        0      2
# 5   Djebbour  Algeria     forward      123      3      19        1      0
# 6    Ghezzal  Algeria     forward       40      3       8        0      0
# 7  Guedioura  Algeria  midfielder       38      0      18        1      0
# 8   Halliche  Algeria    defender      270      2      94        4      0
# 9      Kadir  Algeria  midfielder      262      0     104        3      0
#
#    Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0         NaN         NaN  ...          NaN          NaN          NaN
# ...

# %%
player_df.iloc[ [3,5,6,1] ,[1,2,4,7] ]
# Out:
#       team  position  shots  saves
# 3  Algeria  defender      1      0
# 5  Algeria   forward      3      0
# 6  Algeria   forward      3      0
# 1  Algeria  defender      1      0

# %%
player_df.iloc[2:6,0:2]
# Out:
#      surname     team
# 2  Boudebouz  Algeria
# 3  Bougherra  Algeria
# 4   Chaouchi  Algeria
# 5   Djebbour  Algeria

# %%
player_df.iloc[2:11:2,0:2]
# Out:
#       surname     team
# 2   Boudebouz  Algeria
# 4    Chaouchi  Algeria
# 6     Ghezzal  Algeria
# 8    Halliche  Algeria
# 10      Lacen  Algeria

# %%
name_team_df = player_df.iloc[2:11:2,0:2]

# %%
name_team_df.columns
# Out:
# Index(['surname', 'team'], dtype='object')

# %%
player_df = player_df.iloc[ : , :8 ]
player_df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 2        0
# 3        0
# 4        2
# ..     ...
# ...

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   surname   595 non-null    object
#  1   team      595 non-null    object
#  2   position  595 non-null    object
#  3   minutes   595 non-null    int64
#  4   shots     595 non-null    int64
#  5   passes    595 non-null    int64
#  6   tackles   595 non-null    int64
#  7   saves     595 non-null    int64
# dtypes: int64(5), object(3)
# memory usage: 37.3+ KB

# %%
player_df.iloc[:,:2]
# Out:
#            surname     team
# 0           Abdoun  Algeria
# 1          Belhadj  Algeria
# 2        Boudebouz  Algeria
# 3        Bougherra  Algeria
# 4         Chaouchi  Algeria
# ..             ...      ...
# 590         Holden      USA
# 591         Howard      USA
# 592  Jozy Altidore      USA
# 593         Onyewu      USA
# 594         Torres      USA
#
# [595 rows x 2 columns]

# %%
player_df.iloc[ :, 0] # Series all rows of column 0
# Out:
# 0             Abdoun
# 1            Belhadj
# 2          Boudebouz
# 3          Bougherra
# 4           Chaouchi
#            ...
# 590           Holden
# 591           Howard
# 592    Jozy Altidore
# 593           Onyewu
# 594           Torres
# Name: surname, Length: 595, dtype: object

# %%
r0cAll = player_df.iloc[0,:] # Serires row 0 all columns
type(r0cAll)
# Out:
# pandas.core.series.Series

# %%
r0cAll.shape # have only one dimension
# Out:
# (8,)

# %%
player_df.set_index('surname') # change the index to surname
# Out:
#                   team    position  minutes  shots  passes  tackles  saves
# surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [595 rows x 7 columns]

# %%
player_df # not implpace, so the original dataframe is not changed
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 2        0
# 3        0
# 4        2
# ..     ...
# ...

# %%
surname_index = player_df.set_index('surname')
surname_index.head()
# Out:
#               team    position  minutes  shots  passes  tackles  saves
# surname
# Abdoun     Algeria  midfielder       16      0       6        0      0
# Belhadj    Algeria    defender      270      1     146        8      0
# Boudebouz  Algeria  midfielder       74      3      28        1      0
# Bougherra  Algeria    defender      270      1      89       11      0
# Chaouchi   Algeria  goalkeeper       90      0      17        0      2

# %%
surname_index = surname_index.reset_index() # reset the index to default

# %%
surname_index.head(3)
# Out:
#      surname     team    position  minutes  shots  passes  tackles  saves
# 0     Abdoun  Algeria  midfielder       16      0       6        0      0
# 1    Belhadj  Algeria    defender      270      1     146        8      0
# 2  Boudebouz  Algeria  midfielder       74      3      28        1      0

# %%
player_df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 2        0
# 3        0
# 4        2
# ..     ...
# ...

# %%
player_df.set_index('surname', inplace=True) # change the index to surname

# %%
player_df.loc['Belhadj','team']
# Out:
# 'Algeria'

# %%
player_df.loc[['Abdoun','Bougherra','Howard'],['team','position']]
# Out:
#               team    position
# surname
# Abdoun     Algeria  midfielder
# Bougherra  Algeria    defender
# Howard         USA  goalkeeper

# %%
player_df.loc['Boudebouz':'Chaouchi',['team','position']] # slicing the last row is included
# Out:
#               team    position
# surname
# Boudebouz  Algeria  midfielder
# Bougherra  Algeria    defender
# Chaouchi   Algeria  goalkeeper

# %% [markdown]
# # Short Forms

# %%
player_df.loc[:,['passes']] # regular form
# Out:
#                passes
# surname
# Abdoun              6
# Belhadj           146
# Boudebouz          28
# Bougherra          89
# Chaouchi           17
# ...               ...
# Holden              2
# Howard             81
# Jozy Altidore      84
# Onyewu             69
# Torres             32
#
# [595 rows x 1 columns]

# %%
player_df['passes'] # short form
# Out:
# surname
# Abdoun             6
# Belhadj          146
# Boudebouz         28
# Bougherra         89
# Chaouchi          17
#                 ...
# Holden             2
# Howard            81
# Jozy Altidore     84
# Onyewu            69
# Torres            32
# Name: passes, Length: 595, dtype: int64

# %%
player_df.passes # short form 2 to select a column (select using attribute)
# Out:
# surname
# Abdoun             6
# Belhadj          146
# Boudebouz         28
# Bougherra         89
# Chaouchi          17
#                 ...
# Holden             2
# Howard            81
# Jozy Altidore     84
# Onyewu            69
# Torres            32
# Name: passes, Length: 595, dtype: int64

# %%
player_df.iloc[0],player_df.iloc[1]
# Out:
# (team           Algeria
#  position    midfielder
#  minutes             16
#  shots                0
#  passes               6
#  tackles              0
#  saves                0
#  Name: Abdoun, dtype: object,
#  team         Algeria
#  position    defender
#  minutes          270
#  shots              1
#  passes           146
#  tackles            8
#  saves              0
#  Name: Belhadj, dtype: object)

# %% [markdown]
# # Filtering

# %%
player_df.reset_index(inplace=True) # reset the index to default

# %%
player_df.loc[ player_df.shots >= 20 , : ]
# Out:
#     surname       team position  minutes  shots  passes  tackles  saves
# 28    Messi  Argentina  forward      450     21     321       10      0
# 200    Gyan      Ghana  forward      501     27     151        1      0
# 535   Villa      Spain  forward      529     22     169        2      0

# %%
player_df[ 300 <= player_df.passes ]
# Out:
#             surname         team    position  minutes  shots  passes  tackles  \
# 28            Messi    Argentina     forward      450     21     321       10
# 183            Lahm      Germany    defender      540      0     360       17
# 189  Schweinsteiger      Germany  midfielder      531      5     423       23
# 195           Annan        Ghana  midfielder      510      4     307       11
# 335      van Bommel  Netherlands  midfielder      540      2     307       31
# 517          Alonso        Spain  midfielder      506      9     465       18
# 519        Busquets        Spain  midfielder      511      0     466       15
# 520       Capdevila        Spain    defender      540      1     310       10
# 530           Pique        Spain    defender      540      2     402       15
# 536            Xavi        Spain  midfielder      515      4     563        6
#
#      saves
# 28       0
# 183      0
# 189      0
# 195      0
# 335      0
# 517      0
# 519      0
# ...

# %%
player_df[ player_df.team == 'England' ].head()
# Out:
#          surname     team    position  minutes  shots  passes  tackles  saves
# 135  Ashley Cole  England    defender      360      0     142       12      0
# 136        Barry  England  midfielder      264      2     171        8      0
# 137    Carragher  England    defender      135      0      74        4      0
# 138       Crouch  England     forward       17      1       7        0      0
# 139        Defoe  England     forward      173      5      17        1      0

# %%
player_df[ player_df.team.str.endswith('land') ].head() # string method can be use if return boolean e.g. str.endswith
# Out:
#          surname     team    position  minutes  shots  passes  tackles  saves
# 135  Ashley Cole  England    defender      360      0     142       12      0
# 136        Barry  England  midfielder      264      2     171        8      0
# 137    Carragher  England    defender      135      0      74        4      0
# 138       Crouch  England     forward       17      1       7        0      0
# 139        Defoe  England     forward      173      5      17        1      0

# %%
player_df[ player_df.surname.str.contains('.*rr.$') ] # filter with regular expression
# Out:
#          surname         team    position  minutes  shots  passes  tackles  \
# 3      Bougherra      Algeria    defender      270      1      89       11
# 136        Barry      England  midfielder      264      2     171        8
# 151        Terry      England    defender      360      2     223        3
# 156  Alou Diarra       France  midfielder       82      0      31        0
# 236    Izaguirre     Honduras    defender      180      0      51        8
# 268        Barry  Ivory Coast  goalkeeper      270      0      23        0
#
#      saves
# 3        0
# 136      0
# 151      0
# 156      0
# 236      0
# 268      8

# %%
player_df[ (player_df.team == 'Spain') & (player_df.passes >= 300) ]
# Out:
#        surname   team    position  minutes  shots  passes  tackles  saves
# 517     Alonso  Spain  midfielder      506      9     465       18      0
# 519   Busquets  Spain  midfielder      511      0     466       15      0
# 520  Capdevila  Spain    defender      540      1     310       10      0
# 530      Pique  Spain    defender      540      2     402       15      0
# 536       Xavi  Spain  midfielder      515      4     563        6      0

# %%
player_df[ (player_df.team == 'Spain') | (player_df.team == 'England') ].head()
# using or if we didn't use the () it will give an error
# because the operator | has higher precedence than == 
# the program will try to evaluate  'Spain' | (player_df.team == 'England') first
# so that's not possible then ERROR!!!!!!!
# Out:
#          surname     team    position  minutes  shots  passes  tackles  saves
# 135  Ashley Cole  England    defender      360      0     142       12      0
# 136        Barry  England  midfielder      264      2     171        8      0
# 137    Carragher  England    defender      135      0      74        4      0
# 138       Crouch  England     forward       17      1       7        0      0
# 139        Defoe  England     forward      173      5      17        1      0

# %% [markdown]
# ### Query

# %%
player_df.query('team == "Spain" and passes >= 300') # like SQL
# Out:
#        surname   team    position  minutes  shots  passes  tackles  saves
# 517     Alonso  Spain  midfielder      506      9     465       18      0
# 519   Busquets  Spain  midfielder      511      0     466       15      0
# 520  Capdevila  Spain    defender      540      1     310       10      0
# 530      Pique  Spain    defender      540      2     402       15      0
# 536       Xavi  Spain  midfielder      515      4     563        6      0

# %% [markdown]
# ## Sorting

# %% [markdown]
# normally sorting is not implace so no change in dataframe

# %%
player_df.sort_values('shots',ascending=False) # sort by default ascending=True
# Out:
#      surname       team    position  minutes  shots  passes  tackles  saves
# 200     Gyan      Ghana     forward      501     27     151        1      0
# 535    Villa      Spain     forward      529     22     169        2      0
# 28     Messi  Argentina     forward      450     21     321       10      0
# 573   Suarez    Uruguay     forward      452     19     127        4      0
# 562   Forlan    Uruguay     forward      564     18     202        0      0
# ..       ...        ...         ...      ...    ...     ...      ...    ...
# 208   Sarpei      Ghana    defender      463      0     167       13      0
# 204  Kingson      Ghana  goalkeeper      510      0     105        1     20
# 194    Amoah      Ghana     forward       11      0       4        1      0
# 193  Adiyiah      Ghana     forward       33      0       9        0      0
# 0     Abdoun    Algeria  midfielder       16      0       6        0      0
#
# [595 rows x 8 columns]

# %%
player_df.sort_values(['passes','minutes'], ascending=[False, True]).head(20)
# Out:
#              surname         team    position  minutes  shots  passes  \
# 536             Xavi        Spain  midfielder      515      4     563
# 519         Busquets        Spain  midfielder      511      0     466
# 517           Alonso        Spain  midfielder      506      9     465
# 189   Schweinsteiger      Germany  midfielder      531      5     423
# 530            Pique        Spain    defender      540      2     402
# 183             Lahm      Germany    defender      540      0     360
# 28             Messi    Argentina     forward      450     21     321
# 520        Capdevila        Spain    defender      540      1     310
# 195            Annan        Ghana  midfielder      510      4     307
# 335       van Bommel  Netherlands  midfielder      540      2     307
# 523          Iniesta        Spain  midfielder      437      8     299
# 62    Gilberto Silva       Brazil  midfielder      450      3     299
# ...

# %% [markdown]
# # Column Calculation

# %% [markdown]
# ## Series and Scalar

# %%
player_df.passes
# Out:
# 0        6
# 1      146
# 2       28
# 3       89
# 4       17
#       ...
# 590      2
# 591     81
# 592     84
# 593     69
# 594     32
# Name: passes, Length: 595, dtype: int64

# %%
player_df.passes + 10 #broadcasting
# Out:
# 0       16
# 1      156
# 2       38
# 3       99
# 4       27
#       ...
# 590     12
# 591     91
# 592     94
# 593     79
# 594     42
# Name: passes, Length: 595, dtype: int64

# %%
player_df.loc[: , 'minutes':'saves'] + 10 #broadcasting to dataframe (all positions)
# Out:
#      minutes  shots  passes  tackles  saves
# 0         26     10      16       10     10
# 1        280     11     156       18     10
# 2         84     13      38       11     10
# 3        280     11      99       21     10
# 4        100     10      27       10     12
# ..       ...    ...     ...      ...    ...
# 590       14     10      12       10     10
# 591      400     10      91       10     24
# 592      366     18      94       12     10
# 593      180     11      79       12     10
# 594       55     11      42       10     10
#
# [595 rows x 5 columns]

# %%
player_df.passes > 100 # broadcasting comparison
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 590    False
# 591    False
# 592    False
# 593    False
# 594    False
# Name: passes, Length: 595, dtype: bool

# %%
player_df[ player_df.minutes ** 0.5 < 10  ]
# Out:
#        surname     team    position  minutes  shots  passes  tackles  saves
# 0       Abdoun  Algeria  midfielder       16      0       6        0      0
# 2    Boudebouz  Algeria  midfielder       74      3      28        1      0
# 4     Chaouchi  Algeria  goalkeeper       90      0      17        0      2
# 6      Ghezzal  Algeria     forward       40      3       8        0      0
# 7    Guedioura  Algeria  midfielder       38      0      18        1      0
# ..         ...      ...         ...      ...    ...     ...      ...    ...
# 576    Beasley      USA  midfielder       10      0       4        0      0
# 580     Buddle      USA     forward       39      1      12        0      0
# 589      Gomez      USA     forward       85      4      18        0      0
# 590     Holden      USA  midfielder        4      0       2        0      0
# 594     Torres      USA  midfielder       45      1      32        0      0
#
# [186 rows x 8 columns]

# %% [markdown]
# ## Series and Series

# %%
player_df.tackles + player_df.shots
# Out:
# 0       0
# 1       9
# 2       4
# 3      12
# 4       0
#        ..
# 590     0
# 591     0
# 592    10
# 593     3
# 594     1
# Length: 595, dtype: int64

# %%
df2 = player_df.sample(5,random_state=7) # random sample of 5 rows
df2
# Out:
#       surname         team    position  minutes  shots  passes  tackles  saves
# 480     Suler     Slovenia    defender      270      0     102        5      0
# 544      Frei  Switzerland     forward       63      2      11        0      0
# 540   Bunjaku  Switzerland     forward       13      0       5        0      0
# 459    Sestak     Slovakia     forward      152      3      27        1      0
# 539  Benaglio  Switzerland  goalkeeper      270      0      75        0     11

# %%
df3 = df2.sample(4, random_state=8)
df3
# Out:
#       surname         team    position  minutes  shots  passes  tackles  saves
# 539  Benaglio  Switzerland  goalkeeper      270      0      75        0     11
# 540   Bunjaku  Switzerland     forward       13      0       5        0      0
# 544      Frei  Switzerland     forward       63      2      11        0      0
# 480     Suler     Slovenia    defender      270      0     102        5      0

# %%
df2.passes + df3.passes 
# adding two dataframes base on index if index is student id 
# then if two dataframs not the same but still same index 
# it will add the value of the same index
# ! if index not the same it will return NaN or some dataframe don't have that index
# why value is become float because NaN is float
# Out:
# 459      NaN
# 480    204.0
# 539    150.0
# 540     10.0
# 544     22.0
# Name: passes, dtype: float64

# %%
df2.passes.add(df3.passes, fill_value=0) # add two dataframes and fill the missing value with 0
# Out:
# 459     27.0
# 480    204.0
# 539    150.0
# 540     10.0
# 544     22.0
# Name: passes, dtype: float64

# %% [markdown]
# ## Column statistics

# %%
player_df.passes.max()
# Out:
# 563

# %%
player_df.passes.mean()
# Out:
# 84.52100840336135

# %%
player_df.passes.aggregate(['max','min','mean','std','sum']) # or .agg() is short form of .aggregate()
# Out:
# max       563.000000
# min         0.000000
# mean       84.521008
# std        77.310368
# sum     50290.000000
# Name: passes, dtype: float64

# %%
player_df.mean(numeric_only=True) # mean of all numeric columns
# Out:
# minutes    208.863866
# shots        2.304202
# passes      84.521008
# tackles      4.191597
# saves        0.667227
# hours        3.481064
# dtype: float64

# %%
player_df.sum(numeric_only=True, axis='rows') # sum of all numeric columns
# Out:
# minutes    124274.000000
# shots        1371.000000
# passes      50290.000000
# tackles      2494.000000
# saves         397.000000
# hours        2071.233333
# dtype: float64

# %%
player_df.sum(numeric_only=True, axis='columns') # sum of all numeric columns
# Out:
# 0       22.266667
# 1      429.500000
# 2      107.233333
# 3      375.500000
# 4      110.500000
#           ...
# 590      6.066667
# 591    491.500000
# 592    455.933333
# 593    244.833333
# 594     78.750000
# Length: 595, dtype: float64

# %% [markdown]
# # Column Creation

# %%
player_df['hours'] = player_df.minutes / 60

# %%
player_df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves     hours
# 0        0  0.266667
# 1        0  4.500000
# 2        0  1.233333
# ...
